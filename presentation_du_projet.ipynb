# %% [markdown]
# # Teen Smartphone Usage and Addiction Impact Dataset 📱 (changer le titre)

# %% [markdown]
# <p align="left">
#   <img src="images/cover_teen_phone_addiction.png" width="750">
# </p>

# %% [markdown]
# #### Présentation du projet
#
# #### Pourquoi ce sujet ?
#
# #### Objectif de notre analyse
#
# #### Équipe

# %%
#import des librairies

# %%
#import du dataset
